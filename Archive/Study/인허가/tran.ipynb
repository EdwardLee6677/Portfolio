# %%
import pandas as pd

# %%
tra=pd.read_csv("C:/Users/Edward/Downloads/ipo.csv")
tra
# Out:
#      Unnamed: 0  전_거래일_거래량     전_거래일_종가        기업명    공모가    기관경쟁률    청약경쟁률  \
# 0             0   657600.0  2477.449951  티쓰리엔터테인먼트   1700  1744.08  1384.30
# 1             1   657600.0  2477.449951       티에프이  10500  1295.18    87.78
# 2             2   758000.0  2483.159912     윤성에프앤씨  49000    67.49     1.73
# 3             3   899000.0  2402.229980     디티앤씨알오  17000    74.53     5.73
# 4             4   550300.0  2329.169922       뉴로메카  16900  1652.13  1181.88
# ..          ...        ...          ...        ...    ...      ...      ...
# 591         591   383700.0  2076.120117      덕신하우징  13000   650.72   899.07
# 592         592   408800.0  2061.969971      창해에탄올   8300   578.20   675.79
# 593         593   323600.0  2026.619995       윈하이텍   8300   444.10   589.58
# 594         594   353500.0  2028.319946      아진엑스텍   7000   478.65   876.27
# 595         595   274600.0  2018.500000  화인베스틸(유가)   4700    85.45   248.12
#
# ...

# %%
tra.to_excel('ipo.xlsx', encoding='utf-8')
# Out:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
