# %%
import pandas as pd
import numpy as np

# %%
pet = pd.read_csv('pet.csv')
pet
# Out:
#        개방서비스명  개방자치단체코드  영업상태구분코드         소재지전화  소재지우편번호  \
# 0        동물병원   3000000         1           NaN      NaN
# 1        동물병원   3000000         3           NaN      NaN
# 2        동물병원   3000000         1      391-4575      NaN
# 3        동물병원   3000000         1       3917502      NaN
# 4        동물병원   3000000         1     3676-1190      NaN
# ...       ...       ...       ...           ...      ...
# 105894  동물미용업   6520000         1           NaN      NaN
# 105895  동물미용업   6520000         1           NaN      NaN
# 105896  동물미용업   6520000         1           NaN      NaN
# 105897  동물미용업   6520000         1           NaN      NaN
# 105898  동물미용업   6520000         3  064-739-7585      NaN
#
#                                  소재지전체주소  \
# 0              서울특별시 종로구 숭인동 20-138 지1층
# 1              서울특별시 종로구 평창동 289-2   번지
# 2       서울특별시 종로구 홍지동 127-7번지 5통5반 지층 3호
# 3                 서울특별시 종로구 홍지동 126-8번지
# 4                  서울특별시 종로구 숭인동 52-8번지
# ...

# %%
filtered_df = pet.loc[pet['영업상태구분코드'].isin([1])]

# %%
filtered_df['폐업일자'] = filtered_df['폐업일자'].astype(str)

# %%
pet_filter = pet[pet['소재지전체주소'].str.contains('대구광역시')]
print(pet_filter)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Edward\Desktop\PythonWorkspace\인허가\pet.ipynb 셀 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Edward/Desktop/PythonWorkspace/%EC%9D%B8%ED%97%88%EA%B0%80/pet.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> pet_filter = pet[pet['소재지전체주소'].str.contains('대구광역시')]
#       <a href='vscode-notebook-cell:/c%3A/Users/Edward/Desktop/PythonWorkspace/%EC%9D%B8%ED%97%88%EA%B0%80/pet.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> print(pet_filter)
#
# File c:\Users\Edward\anaconda3\envs\py\lib\site-packages\pandas\core\frame.py:3495, in DataFrame.__getitem__(self, key)
#    3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
# -> 3495 if com.is_bool_indexer(key):
#    3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
# ...
