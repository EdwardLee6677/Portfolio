# %%
import pandas as pd
import numpy as np

# %%
df_o=pd.read_csv('C:/Users/Edward/Desktop/PythonWorkspace/인허가/df_o.csv', encoding='cp949', index_col=[0])
df_o
# Out:
#             가축분뇨 수집운반업  가축분뇨배출시설관리업(사업장)  가축사육업  가축인공수정소  개인하수처리시설관리업(사업장)  \
# 개업시기
# 2020-01-22           0                 0     28        1                 0
# 2020-01-23           0                 0     21        1                 0
# 2020-01-24           0                 0      1        0                 0
# 2020-01-25           0                 0      2        0                 0
# 2020-01-26           0                 0      0        0                 0
# ...                ...               ...    ...      ...               ...
# 2022-12-27           0                 1     15        1                 0
# 2022-12-28           0                 0     14        0                 0
# 2022-12-29           0                 2     11        1                 0
# 2022-12-30           0                 0     16        0                 0
# 2022-12-31           0                 0      0        0                 0
#
# ...

# %%
df_o = df_o.fillna(0)
df_o
# Out:
#             가축분뇨 수집운반업  가축분뇨배출시설관리업(사업장)  가축사육업  가축인공수정소  개인하수처리시설관리업(사업장)  \
# 개업시기
# 2020-01-22           0                 0     28        1                 0
# 2020-01-23           0                 0     21        1                 0
# 2020-01-24           0                 0      1        0                 0
# 2020-01-25           0                 0      2        0                 0
# 2020-01-26           0                 0      0        0                 0
# ...                ...               ...    ...      ...               ...
# 2022-12-27           0                 1     15        1                 0
# 2022-12-28           0                 0     14        0                 0
# 2022-12-29           0                 2     11        1                 0
# 2022-12-30           0                 0     16        0                 0
# 2022-12-31           0                 0      0        0                 0
#
# ...

# %%
df_c=pd.read_csv('C:/Users/Edward/Desktop/PythonWorkspace/인허가/df_c.csv', encoding='cp949', index_col=[0])
df_c
# Out:
#             가축분뇨 수집운반업  가축분뇨배출시설관리업(사업장)  가축사육업  가축인공수정소  개인하수처리시설관리업(사업장)  \
# 폐업시기
# 2020-01-22           0                 0     51        0                 0
# 2020-01-23           0                 0     18        0                 0
# 2020-01-24           0                 0      0        0                 0
# 2020-01-25           0                 0      0        0                 0
# 2020-01-26           0                 0      0        0                 0
# ...                ...               ...    ...      ...               ...
# 2022-12-27           0                 1     34        0                 1
# 2022-12-28           0                 0     33        0                 0
# 2022-12-29           0                 0     38        0                 0
# 2022-12-30           0                 0     12        0                 2
# 2022-12-31           0                 0      0        0                 0
#
# ...

# %%
df_c = df_c.fillna(0)
df_c
# Out:
#             가축분뇨 수집운반업  가축분뇨배출시설관리업(사업장)  가축사육업  가축인공수정소  개인하수처리시설관리업(사업장)  \
# 폐업시기
# 2020-01-22           0                 0     51        0                 0
# 2020-01-23           0                 0     18        0                 0
# 2020-01-24           0                 0      0        0                 0
# 2020-01-25           0                 0      0        0                 0
# 2020-01-26           0                 0      0        0                 0
# ...                ...               ...    ...      ...               ...
# 2022-12-27           0                 1     34        0                 1
# 2022-12-28           0                 0     33        0                 0
# 2022-12-29           0                 0     38        0                 0
# 2022-12-30           0                 0     12        0                 2
# 2022-12-31           0                 0      0        0                 0
#
# ...

# %%
df_c.to_csv('C:/Users/Edward/Desktop/PythonWorkspace/인허가/df_c.csv', encoding='cp949')
df_o.to_csv('C:/Users/Edward/Desktop/PythonWorkspace/인허가/df_o.csv', encoding= 'cp949')
