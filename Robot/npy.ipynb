# %%
import numpy as np

# 파일 경로
file_path = "bottle.npy"

# 불러오기
data = np.load(file_path, allow_pickle=True)

# 확인
print(type(data))   
print(data.shape)     
print(data)
# Out:
# <class 'numpy.ndarray'>
# (1,)
# [{'robot_state': array([[-3.31609065, -1.78019792,  2.46087909, ...,  0.00779242,
#           0.        ,  0.        ],
#         [-3.31605488, -1.78023369,  2.46090269, ...,  0.00781055,
#           0.        ,  0.        ],
#         [-3.31609065, -1.78024561,  2.46089053, ...,  0.00781239,
#           0.        ,  0.        ],
#         ...,
#         [-3.27536089, -1.27687484,  2.13911963, ...,  0.08057259,
#           0.        ,  0.        ],
#         [-3.2748943 , -1.27727062,  2.13182831, ...,  0.07685368,
#           0.        ,  0.        ],
#         [-3.2749179 , -1.27723486,  2.13306189, ...,  0.07753054,
#           0.        ,  0.        ]], shape=(95, 15)), 'action': array([[-0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00],
#         [-0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
# ...
