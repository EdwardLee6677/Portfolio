# %% [markdown]
# ## 9월 11일

# %% [markdown]
# - 지도학습: 입력(데이터)과 타겡(정답)으로 이뤄진 훈련데이터다 필요
# - 비지도 학습: 입력데이터만 이용
# ![image.png](attachment:image.png)

# %%
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8, 
                10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7, 
                7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
fish_data = [[l, w] for l, w in zip(fish_length, fish_weight)]
fish_target = [1]*35 + [0]*14

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()

# %% [markdown]
# 배열의 위치: 인덱스

# %%
# fish_data의 5번째 샘플 출력
print(fish_data[4])
# fish_data의 1~5번째 샘플 출력
print(fish_data[0:5])
# fish_data의 처음부터 5번째 샘플 출력
print(fish_data[:5])
# fish_data의 44번째 샘플부터 마지막 샘플까지 출력
print(fish_data[44:])
# Out:
# [29.0, 430.0]
# [[25.4, 242.0], [26.3, 290.0], [26.5, 340.0], [29.0, 363.0], [29.0, 430.0]]
# [[25.4, 242.0], [26.3, 290.0], [26.5, 340.0], [29.0, 363.0], [29.0, 430.0]]
# [[12.2, 12.2], [12.4, 13.4], [13.0, 12.2], [14.3, 19.7], [15.0, 19.9]]

# %% [markdown]
# ### 샘플링 편향

# %%
train_input = fish_data[:35]
train_target = fish_target[:35]

test_input = fish_data[35:]
test_target = fish_target[35:]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kn = kn.fit(train_input, train_target)
kn.score(test_input, test_target)
# Out:
# 0.0

# %% [markdown]
# ### numpy 사용하기

# %%
import numpy as np

input_arr = np.array(fish_data)
target_arr = np.array(fish_target)

print(input_arr)
# Out:
# array([[  25.4,  242. ],
#        [  26.3,  290. ],
#        [  26.5,  340. ],
#        [  29. ,  363. ],
#        [  29. ,  430. ],
#        [  29.7,  450. ],
#        [  29.7,  500. ],
#        [  30. ,  390. ],
#        [  30. ,  450. ],
#        [  30.7,  500. ],
#        [  31. ,  475. ],
#        [  31. ,  500. ],
#        [  31.5,  500. ],
#        [  32. ,  340. ],
#        [  32. ,  600. ],
#        [  32. ,  600. ],
#        [  33. ,  700. ],
#        [  33. ,  700. ],
#        [  33.5,  610. ],
#        [  33.5,  650. ],
#        [  34. ,  575. ],
#        [  34. ,  685. ],
#        [  34.5,  620. ],
#        [  35. ,  680. ],
#        [  35. ,  700. ],
#        [  35. ,  725. ],
#        [  35. ,  720. ],
#        [  36. ,  714. ],
#        [  36. ,  850. ],
#        [  37. , 1000. ],
#        [  38.5,  920. ],
#        [  38.5,  955. ],
#        [  39.5,  925. ],
#        [  41. ,  975. ],
#        [  41. ,  950. ],
#        [   9.8,    6.7],
#        [  10.5,    7.5],
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
input_arr.shape
# Out:
# (49, 2)

# %% [markdown]
# 배열의 종류:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 데이터 섞기

# %%
# 데이터 섞기 (랜덤하게 섞기) - 실제로 쓸때는 42를 사용하지 않음
np.random.seed(42)
index = np.arange(49)
np.random.shuffle(index)
index
# Out:
# array([13, 45, 47, 44, 17, 27, 26, 25, 31, 19, 12,  4, 34,  8,  3,  6, 40,
#        41, 46, 15,  9, 16, 24, 33, 30,  0, 43, 32,  5, 29, 11, 36,  1, 21,
#         2, 37, 35, 23, 39, 10, 22, 18, 48, 20,  7, 42, 14, 28, 38])

# %%
# 샘플 확인
input_arr[[1, 3]]
# Out:
# array([[ 26.3, 290. ],
#        [ 29. , 363. ]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 9월

# %%
# 섞은 index로 input_arr와 target_arr를 섞기
train_input = input_arr[index[:35]]
train_target = target_arr[index[:35]]

# %%
print(input_arr[13], train_input[0])
# Out:
# [ 32. 340.] [ 32. 340.]
