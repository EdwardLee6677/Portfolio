# %% [markdown]
# ## 데이터 전처리

# %%
import pandas as pd
import numpy as np
import string
import re

## NLTK stopwords
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
# stopwords
def set_stop_words():
    stop_words = stopwords.words('english')
    stop_words.extend(['from', 'subject', 're', 'edu',
    'use', 'not', 'would', 'say', 'could', '_', 'be', 'know',
    'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some',
    'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily',
    'lot', 'lack', 'make', 'want', 'seem', 'run', 'need',
    'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come',
    'app', 'non'])
    
    return stop_words
stop_words = set_stop_words()

# %%
def preprocess_text(text_data, get_lemma=True, tags=(), stop_words=[]):
    # 소문자 변경
    text_data = text_data.lower()
    # URL 제거
    text_data = re.sub(r'((www.\S+)|(https?://\S+))', r"", text_data)
    # HTML 태그 제거
    text_data = re.sub(r'<[^>]+>', r'', text_data)
    # 숫자 제거
    text_data = re.sub(r'[0-9]\S+', r'', text_data)
    # 문장부호 제거
    text_data = [char for char in text_data if char not in string.punctuation]
    text_data = "".join(text_data)
    # 금지어 제거
    text_data = [word for word in text_data.split() if word.lower() not in stop_words]
    text_data = " ".join(text_data)
    # 래마타이즈
    if get_lemma == True:
        text_data = [lemmatizer.lemmatize(word) for word in text_data.split()]
        text_data = " ".join(text_data)
    # POS 필터
    if len(tags) > 0:
        text_data = [word for word, pos in nltk.pos_tag(nltk.word_tokenize(text_data)) if
                     pos.startswith(tags)]
        text_data = " ".join(text_data)
    
    return text_data

# %%
# 데이터 불러오기
file_name = "Womens Clothing E-Commerce Reviews.csv"
df = pd.read_csv(file_name)
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
df.shape
# Out:
# (23486, 11)

# %%
df2 = df.dropna(subset=['Review Text'])
df2.shape
# Out:
# (22641, 11)

# %%
data = df2.copy()

# %%
TAGS = ('JJ', 'NN', 'RB', 'VB')

# %%
data['Review Text2'] = data['Review Text'].apply(lambda x: preprocess_text(x, get_lemma=True, tags=TAGS, stop_words=stop_words))

# %%
data['Review Text2']
# Out:
# 0              absolutely wonderful silky sexy comfortable
# 1        love dress sooo pretty happened find store im ...
# 2        high hope dress really wanted work initially o...
# 3        love love love jumpsuit fun flirty fabulous ti...
# 4        shirt flattering due adjustable front tie perf...
#                                ...
# 23481    happy snag dress great price slip flattering c...
# 23482    reminds maternity clothes soft stretchy shiny ...
# 23483    fit well top never worked im glad able store d...
# 23484    bought dress wedding summer cute unfortunately...
# 23485    dress lovely platinum feminine fit perfectly w...
# Name: Review Text2, Length: 22641, dtype: object

# %%
import gensim

def sent_to_words(sentences):
    for sent in sentences:
        sent = gensim.utils.simple_preprocess(str(sent), deacc=True)
        yield(sent)

# %%
# Convert to list
dataset = data['Review Text2'].values.tolist()
data_words = list(sent_to_words(dataset))
print(data_words[:1])
# Out:
# [['absolutely', 'wonderful', 'silky', 'sexy', 'comfortable']]

# %% [markdown]
# ## LDA Modeling

# %%
# import packages for LDA
import gensim
import logging
import warnings
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Library for visualization
import matplotlib.pyplot as plt

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) 
# higher threshold fewer phrases.
bigram_mod = gensim.models.phrases.Phraser(bigram)

trigram = gensim.models.Phrases(bigram[data_words], threshold=100)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
bigram.export_phrases()
# Out:
# {'tracy_reese': 6149.393939393939,
#  'foot_tall': 108.95927420737912,
#  'lower_half': 120.09152830991911,
#  'hourglass_figure': 133.73052959501558,
#  'average_height': 138.34357841967056,
#  'took_chance': 285.04582651391166,
#  'form_fitting': 406.9405864197531,
#  'others_mentioned': 138.37484170536092,
#  'dry_cleaned': 447.99107142857144,
#  'month_ago': 216.65124555160142,
#  'added_bonus': 335.25468587296075,
#  'pilcro_stet': 199.45663397005677,
#  'reasonably_priced': 1006.11328125,
#  'visual_interest': 1396.436746987952,
#  'cowl_neck': 206.72577288941736,
#  'elastic_waistband': 149.03132075471697,
#  'cant_wait': 164.7727443778788,
#  'wish_list': 122.38103070175438,
#  'couldve_gotten': 120.80909943714822,
#  'football_player': 5365.9375,
#  'cami_underneath': 109.89607460685114,
#  'baby_doll': 1015.101156069364,
#  'body_type': 118.72181548602201,
#  'last_week': 106.23759468039897,
#  'cold_water': 614.7641975308642,
#  'burnt_orange': 358.84096024006,
#  'real_life': 838.5837209302326,
#  'caught_eye': 714.7751551682979,
#  'scoop_neck': 150.98637931034483,
#  'gave_star': 261.6533333333333,
#  'numerous_compliment': 129.7883597883598,
#  'hot_humid': 463.14840279246874,
#  'broad_shoulder': 123.8584389493257,
#  'strapless_bra': 121.5936463706706,
#  'year_round': 236.9230769230769,
#  'reviewer_mentioned': 116.59458711789387,
#  'hide_tummy': 139.63946869070207,
#  'dry_clean': 540.3461538461538,
#  'add_interest': 144.07680722891564,
#  'forest_green': 126.35645604395603,
#  'reviewer_noted': 105.72914172339479,
#  'sensitive_skin': 229.22451456310682,
#  'read_review': 107.68183686590288,
#  'ended_buying': 102.01402091254752,
#  'holiday_party': 382.75335266400873,
#  'based_review': 101.66385278703733,
#  'title_say': 187.0479302832244,
#  'pleasantly_surprised': 783.073076923077,
#  'ballet_flat': 237.25589535740605,
#  'pear_shaped': 1038.3068783068784,
#  'peachy_pink': 139.52600216684723,
#  'cooler_weather': 145.9609851787271,
#  'metallic_thread': 396.61995688327687,
#  'raw_edge': 903.7368421052631,
#  'machine_washable': 1396.323076923077,
#  'statement_necklace': 371.8007939372068,
#  'week_ago': 214.8165137614679,
#  'agree_reviewer': 109.8553938108551,
#  'fully_lined': 383.28125,
#  'new_favorite': 121.53387259858442,
#  'pilcro_hyphen': 250.19560226068526,
#  'hyphen_chino': 1036.6393188854488,
#  'vertical_stripe': 154.99623890476906,
#  'trying_decide': 141.35195035460993,
#  'gentle_cycle': 1416.6074999999998,
#  'tumble_dry': 167.25,
#  'highly_recommend': 215.91066334819402,
#  'excited_receive': 230.67201834862385,
#  'rehearsal_dinner': 1081.2323838080958,
#  'wont_regret': 256.8485277908991,
#  'polka_dot': 1755.486641221374,
#  'ton_compliment': 147.72164603546335,
#  'paying_full': 117.2668912766345,
#  'cloth_stone': 2012.2265625,
#  'last_year': 100.708446866485,
#  'pay_shipping': 129.10526315789474,
#  'year_ago': 143.5,
#  'camisole_underneath': 102.04635499207608,
#  'nude_bra': 113.9349739243807,
#  'exceeded_expectation': 2612.2210953346857,
#  'previous_reviewer': 117.353987153692,
#  'light_airy': 107.48012461238497,
#  'adding_bulk': 223.8722294654498,
#  'rave_review': 107.22939217318901,
#  'boiled_wool': 946.9301470588235,
#  'first_sight': 169.59198454852728,
#  'paid_full': 176.28693106201754,
#  'year_old': 116.51315789473684,
#  'rib_cage': 3132.5472972972975,
#  'wiggle_room': 257.0508982035928,
#  'byron_lars': 6868.400000000001,
#  'everywhere_else': 273.175,
#  'online_exclusive': 109.10408964879852,
#  'mustard_yellow': 143.9916142557652,
#  'washing_instruction': 178.52365274649108,
#  'tag_say': 102.87636165577342,
#  'get_colder': 179.9895178197065,
#  'olive_green': 109.50892857142857,
#  'personal_preference': 2245.553618134263,
#  'drive_crazy': 357.2330097087379,
#  'faux_leather': 241.9460390355913,
#  'raise_arm': 110.94288421778084,
#  'horizontal_stripe': 250.6579801038062,
#  'ever_owned': 290.6689655172414,
#  'inner_lining': 122.01614987080103,
#  'looking_forward': 124.73004625237192,
#  'hour_glass': 764.6119592875318,
#  'hd_paris': 5110.416666666666,
#  'plenty_room': 153.46322280811512,
#  'pale_skin': 175.88536563641222,
#  'special_occasion': 126.00440292596562,
#  'faux_fur': 1601.7723880597016,
#  'broad_shouldered': 604.612676056338,
#  'gift_card': 733.8034188034188,
#  'slight_sheen': 187.7295918367347,
#  'reading_review': 144.32132028341164,
#  'bathing_suit': 604.4853317285994,
#  'beach_coverup': 376.878429459822,
#  'outer_shell': 273.27851458885937,
#  'baby_bump': 150.55432876534388,
#  'lie_flat': 106.10610875706215,
#  'flip_flop': 4557.520222446917,
#  'write_review': 127.7626800361401,
#  'become_goto': 147.77108433734938,
#  'opened_package': 801.2485859728506,
#  'washing_drying': 117.66331658291458,
#  'athletic_build': 567.0913978494624,
#  'mid_section': 487.8125,
#  'quickly_become': 142.675529705027,
#  'highly_recommended': 150.09615384615384,
#  'degree_weather': 130.52280405405406,
#  'cover_bum': 171.4052795031056,
#  'cant_speak': 109.13771186440678,
#  'add_bulk': 112.0360576923077,
#  'description_say': 278.4623323013416,
#  'bell_shaped': 102.06657420249653,
#  'around_house': 290.8695652173913,
#  'dressing_room': 222.77744510978044,
#  'prettier_person': 126.77869233503787,
#  'laid_flat': 102.31660487288136,
#  'cowboy_boot': 149.26977687626777,
#  'please_bring': 172.74647887323943,
#  'dusty_rose': 627.5950292397661,
#  'worth_penny': 383.8964686998395,
#  'addition_wardrobe': 166.70873786407768,
#  'finger_crossed': 2817.1171875,
#  'slimming_effect': 155.86021505376345,
#  'lay_flat': 151.34331137447032,
#  'couldnt_resist': 283.64939870490286,
#  'christmas_gift': 155.39366515837105,
#  'outer_layer': 139.34201183431955,
#  'start_saying': 380.49375,
#  'cocktail_party': 289.3988764044944,
#  'birthday_gift': 287.1404682274247,
#  'live_south': 113.56481481481481,
#  'swim_suit': 115.278452685422,
#  'pleasant_surprise': 760.6201550387597,
#  'computer_screen': 1807.4736842105262,
#  'army_green': 176.89903846153848,
#  'immediately_drawn': 163.84541984732826,
#  'post_baby': 439.322467544774,
#  'hei_hei': 1957.494,
#  'warmer_weather': 156.27220077220076,
#  'mara_hoffman': 12878.25,
#  'month_pregnant': 199.2611790190314,
#  'followed_advice': 600.3846153846154,
#  'deal_breaker': 1396.2388392857142,
#  'running_errand': 695.6658209199542,
#  'strap_adjustable': 107.5877192982456,
#  'worth_money': 126.92933175635717,
#  'stop_thinking': 119.31407583879293,
#  'live_florida': 227.12962962962962,
#  'spend_money': 271.8005540166205,
#  'post_partum': 1206.3934426229507,
#  'washed_according': 191.74762702400895,
#  'stevie_ankle': 110.75206398348813,
#  'chemical_smell': 1192.4305555555554,
#  'fur_collar': 144.2941176470588,
#  'bridal_shower': 3808.084677419355,
#  'sewn_shut': 676.78490990991,
#  'free_shipping': 1051.2857142857144,
#  'turtle_neck': 194.28394396551724,
#  'hide_imperfection': 270.5514705882353,
#  'birthday_discount': 315.4500918554807,
#  'widest_part': 133.9972253533339,
#  'disagree_previous': 132.79113230650253,
#  'hug_place': 112.00528700906344,
#  'pay_full': 132.90247678018574,
#  'lump_bump': 1751.624778237729,
#  'delicate_cycle': 174.62033898305086,
#  'put_together': 119.03699312783829,
#  'pet_peeve': 3679.5,
#  'hook_eye': 309.89720652856244,
#  'customer_service': 2923.1841109709962,
#  'kelly_green': 176.89903846153848,
#  'date_night': 380.7879952690716,
#  'safety_pin': 2081.3333333333335,
#  'teeny_tiny': 111.35538261997405,
#  'upcoming_trip': 377.38461538461536,
#  'took_plunge': 183.14253393665157,
#  'eva_franco': 12719.25925925926,
#  'muscular_thigh': 172.9453237410072,
#  'get_cooler': 153.86200716845877,
#  'missed_mark': 339.34782608695656,
#  'mock_neck': 197.36781609195404,
#  'tennis_shoe': 232.66937669376694,
#  'colder_month': 121.06056536627945,
#  'according_direction': 353.3127572016461,
#  'air_dry': 144.73557692307693,
#  'skin_tone': 273.1781838949172,
#  'dry_cleaning': 481.4772727272727,
#  'post_pregnancy': 263.8985655737705,
#  'heeled_sandal': 103.85685483870968,
#  'accentuates_curve': 144.2941176470588,
#  'ag_stevie': 894.3229166666666,
#  'knitted_knotted': 722.4824684431977,
#  'falling_apart': 178.4,
#  'holding_horse': 2449.956575682382,
#  'strappy_sandal': 180.62061711079943,
#  'couldnt_happier': 291.7842493847416,
#  'moulinette_soeurs': 4292.75,
#  'let_start': 143.35714285714286,
#  'mid_thigh': 154.41546762589928,
#  'meet_expectation': 161.48275862068968,
#  'trouble_finding': 114.63637172868079,
#  'mock_turtleneck': 275.1762820512821,
#  'room_spare': 264.39520958083835,
#  'colder_weather': 118.20933197348292,
#  'care_instruction': 195.91658215010142,
#  'knocked_star': 286.18333333333334,
#  'crushed_velvet': 221.2757731958763,
#  'air_dried': 291.36312217194575,
#  'potato_sack': 1261.4141414141413,
#  'meadow_rue': 8920.0,
#  'everyone_else': 124.23462532299742,
#  'hug_curve': 130.08333333333334,
#  'audrey_hepburn': 6132.5,
#  'lounging_around': 127.98260869565217,
#  'new_england': 249.57848837209303,
#  'southern_california': 1981.269230769231,
#  'gape_open': 112.49344863731656,
#  'eye_catching': 740.5773305084746,
#  'natural_fiber': 483.2363977485929,
#  'defeat_purpose': 2094.024390243903,
#  'swim_coverup': 218.27542372881356,
#  'broad_shouldersback': 690.9859154929577,
#  'dry_cleaner': 334.5,
#  'blown_away': 268.57664233576645,
#  'comfort_zone': 245.3,
#  'angel_north': 5853.75,
#  'charlie_trouser': 510.70389953734303,
#  'trench_coat': 114.09302325581396,
#  'aesthetically_pleasing': 2453.0,
#  'retro_vibe': 106.3219814241486,
#  'weather_warms': 107.0956340956341,
#  'dragging_ground': 639.1191066997519,
#  'pilcro_serif': 144.0520134228188,
#  'left_center': 142.69529085872577,
#  'taking_tailor': 104.06666666666666,
#  'jewel_tone': 332.9864253393665,
#  'associate_suggested': 194.2420814479638,
#  'citizen_humanity': 3504.285714285714,
#  'frayed_edge': 100.41520467836257,
#  'mid_calf': 112.14080459770115,
#  'draw_string': 507.5172413793103,
#  'pom_pom': 1589.9074074074074,
#  'stain_remover': 1561.0,
#  'vegan_leather': 211.9004524886878,
#  'curvymuscular_frame': 221.5295298165138}

# %%
trigram.export_phrases()
# Out:
# {'tracy_reese': 1695460.0,
#  'foot_tall': 165.49909971705392,
#  'lower_half': 159.45036544850498,
#  'hourglass_figure': 221.1289297068174,
#  'average_height': 176.34915865384616,
#  'took_chance': 784.8968001695274,
#  'form_fitting': 2052.981086028066,
#  'others_mentioned': 405.96160972356034,
#  'dry_cleaned': 3518.525179856115,
#  'month_ago': 4176.009852216749,
#  'someone_else': 129.30074046534685,
#  'added_bonus': 547.6763717805152,
#  'pilcro_stet': 395.2121212121212,
#  'reasonably_priced': 5016.153846153847,
#  'lot_compliment': 109.60603721807735,
#  'visual_interest': 10296.315789473683,
#  'cowl_neck': 549.4367295990014,
#  'warmer_climate': 111.32735808792147,
#  'elastic_waistband': 206.28980125163332,
#  'cant_wait': 694.2230015342706,
#  'wish_list': 316.0812826249068,
#  'couldve_gotten': 163.84422110552765,
#  'football_player': 104336.0,
#  'cami_underneath': 207.6807172487622,
#  'baby_doll': 16578.813559322032,
#  'body_type': 340.59444725545563,
#  'last_week': 243.56876061120542,
#  'cold_water': 2271.57957957958,
#  'hang_dry': 117.79189635304743,
#  'burnt_orange': 921.696113074205,
#  'real_life': 3764.7010309278353,
#  'caught_eye': 6410.70824524313,
#  'hide_flaw': 119.46870229007634,
#  'scoop_neck': 321.23152709359607,
#  'gave_star': 483.3167342211928,
#  'numerous_compliment': 508.8851727982163,
#  'hot_humid': 2083.778195488722,
#  'disagree_reviewer': 115.29534678132283,
#  'broad_shoulder': 679.3756752585276,
#  'strapless_bra': 284.56282262785373,
#  'year_round': 1186.4790334044067,
#  'reading_previous': 202.5469793446187,
#  'previous_review': 244.09507767172,
#  'reviewer_mentioned': 458.73912029144157,
#  'read_previous': 151.64136683676767,
#  'cold_weather': 108.68333333333334,
#  'hide_tummy': 200.64615384615385,
#  'dry_clean': 3844.632391647657,
#  'add_interest': 353.4048983845753,
#  'forest_green': 490.30075187969925,
#  'reviewer_noted': 249.38491937025944,
#  'sensitive_skin': 538.5210210210209,
#  'read_review': 352.166553210801,
#  'ended_buying': 141.18156477497226,
#  'holiday_party': 810.8605656228675,
#  'based_review': 311.6612593755451,
#  'title_say': 460.441306266549,
#  'pleasantly_surprised': 34040.44025157233,
#  'ballet_flat': 918.4507042253522,
#  'pear_shaped': 3648.111888111888,
#  'peachy_pink': 268.9072164948454,
#  'cooler_weather': 302.7607142857143,
#  'metallic_thread': 730.8489773045671,
#  'raw_edge': 2981.0285714285715,
#  'machine_washable': 6660.510697032436,
#  'statement_necklace': 630.0483091787439,
#  'week_ago': 4207.096774193548,
#  'reviewer_stated': 115.00686801539791,
#  'agree_reviewer': 332.0426882432951,
#  'fully_lined': 1439.269949066214,
#  'new_favorite': 218.95670943758245,
#  'pilcro_hyphen': 988.030303030303,
#  'vertical_stripe': 280.171858216971,
#  'trying_decide': 210.48541278708876,
#  'gentle_cycle': 6292.19298245614,
#  'tumble_dry': 1251.031175059952,
#  'based_previous': 129.51983713193306,
#  'highly_recommend': 4020.7642205818497,
#  'excited_receive': 453.8850691791868,
#  'rehearsal_dinner': 7245.555555555555,
#  'wont_regret': 426.75966589167314,
#  'polka_dot': 171605.26315789475,
#  'ton_compliment': 448.64978499761105,
#  'paying_full': 234.8006121163021,
#  'cloth_stone': 13708.920454545456,
#  'last_year': 273.20240900759364,
#  'pay_shipping': 439.1245791245791,
#  'year_ago': 3325.3855721393033,
#  'camisole_underneath': 195.15735328501285,
#  'nude_bra': 240.2394658070458,
#  'exceeded_expectation': 36227.77777777778,
#  'not_wait': 249.8215545921968,
#  'previous_reviewer': 380.08446105481875,
#  'light_airy': 222.92703053165155,
#  'adding_bulk': 463.71555555555557,
#  'boiled_wool': 35693.89473684211,
#  'first_sight': 2240.893470790378,
#  'paid_full': 388.8298136645963,
#  'paid_full_price': 138.57125000000002,
#  'year_old': 295.5184473671248,
#  'wiggle_room': 1441.1049723756905,
#  'byron_lars': 6260160.0,
#  'byron_lars_dress': 345.9722345034928,
#  'everywhere_else': 534.1173029106334,
#  'mustard_yellow': 201.96670538133952,
#  'washing_instruction': 342.87216562602697,
#  'tag_say': 169.85792090930616,
#  'get_colder': 674.0051679586563,
#  'olive_green': 192.41991771882536,
#  'personal_preference': 7410.227272727272,
#  'drive_crazy': 776.3095238095237,
#  'love_first_sight': 162.30855987243805,
#  'faux_leather': 836.6215253029224,
#  'raise_arm': 522.620717291124,
#  'horizontal_stripe': 490.30075187969925,
#  'ever_owned': 570.6733652054129,
#  'inner_lining': 182.38240528858378,
#  'looking_forward': 312.66980612806555,
#  'hour_glass': 2557.254901960784,
#  'hd_paris': 48303.7037037037,
#  'plenty_room': 323.84381401700915,
#  'pale_skin': 333.6291847402959,
#  'special_occasion': 168.00515274199486,
#  'faux_fur': 12327.03213610586,
#  'broad_shouldered': 10868.333333333332,
#  'gift_card': 5114.509803921568,
#  'slight_sheen': 262.32651692926584,
#  'reading_review': 761.3169667212221,
#  'bathing_suit': 34367.432432432426,
#  'beach_coverup': 733.03981264637,
#  'outer_shell': 640.8845208845208,
#  'baby_bump': 315.7869249394673,
#  'week_pregnant': 114.36767929846539,
#  'lie_flat': 214.3051643192488,
#  'flip_flop': 507188.8888888889,
#  'write_review': 668.8205128205128,
#  'become_goto': 156.00478468899522,
#  'opened_package': 1817.7003484320558,
#  'washing_drying': 194.29422718808192,
#  'athletic_build': 2000.3780988050653,
#  'mid_section': 1470.9022556390976,
#  'quickly_become': 202.67288267288268,
#  'highly_recommended': 2649.8031746031747,
#  'degree_weather': 266.16326530612247,
#  'cover_bum': 259.112582781457,
#  'cant_speak': 508.7079473427596,
#  'add_bulk': 218.08404840484047,
#  'positive_review': 105.60323886639675,
#  'description_say': 525.5980948891738,
#  'bell_shaped': 213.45335515548283,
#  'around_house': 358.5040509259259,
#  'dressing_room': 594.7417346312375,
#  'prettier_person': 406.7151767151767,
#  'emerald_green': 104.59749373433584,
#  'christmas_party': 113.45802522836016,
#  'laid_flat': 194.49544324772162,
#  'hate_paying': 120.64754856614246,
#  'cowboy_boot': 436.18729096989966,
#  'please_bring': 229.2379158819837,
#  'laid_flat_dry': 220.77020736352097,
#  'dusty_rose': 1162.3885918003566,
#  'worth_penny': 4521.2266666666665,
#  'pay_attention': 130.28971028971029,
#  'addition_wardrobe': 263.30129471143294,
#  'finger_crossed': 13376.410256410256,
#  'slimming_effect': 210.3678888268503,
#  'lay_flat': 289.8222222222222,
#  'couldnt_resist': 915.4850484346483,
#  'pilcro_chino': 106.81408681408682,
#  'others_noted': 120.15530402737562,
#  'christmas_gift': 269.1847265221878,
#  'outer_layer': 259.89787022045084,
#  'cocktail_party': 680.7481513701609,
#  'birthday_gift': 652.9161451814768,
#  'live_south': 174.94299128101946,
#  'swim_suit': 293.73873873873873,
#  'washing_cold_water': 118.15189491167145,
#  'pleasant_surprise': 2248.6206896551726,
#  'computer_screen': 5434.166666666666,
#  'washed_cold_water': 183.1098631098631,
#  'hung_dry': 174.56248954324911,
#  'army_green': 2353.4436090225568,
#  'immediately_drawn': 231.620218579235,
#  'post_baby': 1729.9631540162122,
#  'hei_hei': 1238990.0,
#  'warmer_weather': 288.65593561368206,
#  'month_pregnant': 374.25032282749055,
#  'followed_advice': 993.6761904761905,
#  'running_errand': 1762.4324324324325,
#  'strap_adjustable': 147.84453441295545,
#  'worth_money': 253.59444444444443,
#  'fair_skin': 117.4954954954955,
#  'stop_thinking': 154.74870751758624,
#  'live_florida': 341.74909924664263,
#  'bathing_suit_cover': 1295.5629139072848,
#  'spend_money': 592.8181818181818,
#  'washed_according': 416.9270729270729,
#  'dry_shrunk': 110.38510368176048,
#  'chemical_smell': 4252.826086956522,
#  'bridal_shower': 68315.23809523809,
#  'sewn_shut': 2237.5980392156866,
#  'free_shipping': 3220.2469135802467,
#  'turtle_neck': 925.9026369168357,
#  'hide_imperfection': 549.1368421052631,
#  'birthday_discount': 554.9787234042553,
#  'widest_part': 328.23825503355704,
#  'disagree_previous': 331.12027927642015,
#  'hug_place': 187.71153700477237,
#  'pay_full': 278.2031495074973,
#  'lump_bump': 12243.510204081633,
#  'say_dry_clean': 247.0660667771726,
#  'delicate_cycle': 490.30075187969925,
#  'ample_room': 128.6700868192581,
#  'put_together': 189.79183802594116,
#  'pet_peeve': 65210.0,
#  'hook_eye': 1316.2176393154894,
#  'customer_service': 41185.26315789473,
#  'kelly_green': 2353.4436090225568,
#  'date_night': 915.5493155493156,
#  'teeny_tiny': 189.70181818181817,
#  'pear_shape': 133.03819161090257,
#  'upcoming_trip': 575.3823529411765,
#  'took_plunge': 439.1245791245791,
#  'muscular_thigh': 281.07758620689657,
#  'get_cooler': 303.30232558139534,
#  'missed_mark': 514.4773175542407,
#  'mock_neck': 1410.8992562542257,
#  'tennis_shoe': 743.1339031339031,
#  'colder_month': 499.6934865900383,
#  'hyphen_chino': 1922.6535626535626,
#  'air_dry': 562.9640287769784,
#  'skin_tone': 647.0766418592506,
#  'dry_cleaning': 3961.5987210231815,
#  'post_pregnancy': 850.5652173913043,
#  'mid_rise': 130.19866227413397,
#  'heeled_sandal': 172.9708222811671,
#  'accentuates_curve': 227.4106364428945,
#  'ag_stevie': 3009.692307692308,
#  'knitted_knotted': 1358.5416666666665,
#  'falling_apart': 232.4777183600713,
#  'couldnt_wait': 105.6587331129163,
#  'holding_horse': 16040.96256684492,
#  'strappy_sandal': 321.23152709359607,
#  'couldnt_happier': 950.1771134279613,
#  'let_start': 198.32389963673228,
#  'mid_thigh': 392.616310892173,
#  'meet_expectation': 301.89814814814815,
#  'trouble_finding': 142.62904636920385,
#  'mock_turtleneck': 1830.4561403508771,
#  'room_spare': 942.2609434764131,
#  'reviewer_pointed': 109.57822214753823,
#  'colder_weather': 465.7857142857143,
#  'elastic_band': 108.66635421548716,
#  'care_instruction': 368.24470588235295,
#  'knocked_star': 3161.6969696969695,
#  'crushed_velvet': 477.72893772893775,
#  'air_dried': 606.6046511627907,
#  'potato_sack': 6955.733333333334,
#  'washing_machine': 115.65132570719163,
#  'nude_colored': 108.25161558071974,
#  'everyone_else': 208.7913093196112,
#  'let_start_saying': 161.19476774127097,
#  'hook_eye_closure': 182.27812718378755,
#  'hug_curve': 232.25853760737482,
#  'lounging_around': 198.8109756097561,
#  'label_say': 103.36437487616405,
#  'southern_california': 6210.47619047619,
#  'caught_attention': 195.43456543456543,
#  'gape_open': 162.86213786213787,
#  'sport_bra': 110.09158823281138,
#  'eye_catching': 14406.860465116279,
#  'natural_fiber': 861.4899082568808,
#  'defeat_purpose': 23712.727272727272,
#  'swim_coverup': 709.7687074829931,
#  'broad_shouldersback': 47425.454545454544,
#  'baby_shower': 315.7869249394673,
#  'body_skimming': 111.82851018220792,
#  'paid_attention': 171.98241758241758,
#  'dry_cleaner': 1876.5467625899282,
#  'comfort_zone': 1811.3888888888887,
#  'running_around': 165.22804054054055,
#  'angel_north': 130420.0,
#  'ton_complement': 103.5079365079365,
#  'charlie_trouser': 1073.4156378600824,
#  'trench_coat': 188.57039580697634,
#  'hourglass_shaped': 100.9963861641714,
#  'free_people': 101.2479378942261,
#  'aesthetically_pleasing': 28982.22222222222,
#  'retro_vibe': 133.76410256410256,
#  'weather_warms': 310.5238095238096,
#  'fyi_broad_shouldersback': 20064.615384615387,
#  'dragging_ground': 1490.5142857142857,
#  'pilcro_serif': 395.2121212121212,
#  'left_center': 187.13299255672138,
#  'taking_tailor': 128.3450877480728,
#  'draw_attention': 110.2451394759087,
#  'jewel_tone': 1260.0966183574878,
#  'associate_suggested': 282.2943722943723,
#  'frayed_edge': 160.27035330261137,
#  'mid_calf': 268.8517831374974,
#  'draw_string': 818.9638932496076,
#  'waste_money': 125.40384615384616,
#  'pom_pom': 32605.0,
#  'stain_remover': 7049.72972972973,
#  'vegan_leather': 427.60655737704917,
#  'chunky_necklace': 114.5542380324989}

# %%
def process_words(texts):
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    
    return texts

# %%
# Prepare documents for Gensim Modeling
documents = process_words(data_words)

# %%
documents[6]
# Out:
# ['aded',
#  'basket',
#  'hte',
#  'last',
#  'mintue',
#  'look',
#  'person',
#  'store',
#  'pick',
#  'went',
#  'teh',
#  'darkler',
#  'color',
#  'pale',
#  'hte',
#  'color',
#  'really',
#  'gorgeous',
#  'turn',
#  'mathced',
#  'everythiing',
#  'trying',
#  'prefectly',
#  'little',
#  'baggy',
#  'hte',
#  'hte',
#  'msallet',
#  'size',
#  'petite',
#  'decided',
#  'jkeep',
#  'said',
#  'matvehd',
#  'everything',
#  'ejans',
#  'pant',
#  'skirt',
#  'waas',
#  'trying',
#  'kept',
#  'oops']

# %%
# Create Dictionary
dictionary = corpora.Dictionary(documents)
for i in range(0, 10):
    print(dictionary[i])
# Out:
# absolutely
# comfortable
# sexy
# silky
# wonderful
# bc
# bought
# definitely
# dress
# find

# %%
print('dictionary size: %d', len(dictionary))
# Out:
# dictionary size: %d 16503

# %%
from collections import Counter

min_count = 20
word_counter = Counter((word for words in documents for word in words))
removal_word_idxs = {
    dictionary.token2id[word] for word, count in word_counter.items() if count < min_count
}

dictionary.filter_tokens(removal_word_idxs)
dictionary.compactify()
print('dictionary size: %d', len(dictionary))
# Out:
# dictionary size: %d 2086
